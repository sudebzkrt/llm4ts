# %%
import numpy as np 
path = "checkpoints/long_term_forecast_co1_comdty_96_LLM4TS_ftS_sl96_ll48_pl96_dm768_nh8_ebtimeF/pred.npy"
pred = np.load(path)
pred.shape
# Out:
# (1504, 96, 1)

# %%
path_true = "checkpoints/long_term_forecast_co1_comdty_96_LLM4TS_ftS_sl96_ll48_pl96_dm768_nh8_ebtimeF/true.npy"
true = np.load(path_true)
true.shape
# Out:
# (1504, 96, 1)

# %%
from sklearn.metrics import mean_squared_error as mse

mse(true.reshape(-1, 1), pred.reshape(-1, 1))
# Out:
# 0.12687062
